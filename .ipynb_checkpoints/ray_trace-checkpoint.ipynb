# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def ray_trace(z_0 = 5, theta_0 = 0, dt = 1e-3, ssp_filename = '2017-002-FA_CTD24.svp'):
    
    # load in SSP table
    ssp_full_filename = '/Users/matthewcasali/Documents/PythonScripts/acoustic-models/SSP_USGS/' + ssp_filename
    try:
        with open(ssp_full_filename, 'r') as file:
            content = file.read()
            content = content.split('\n')[3:-1]
            content = [item.split(' ') for item in content]
            converted_list = np.array([[float(item) for item in sublist] for sublist in content])
            z_ssp = converted_list[:,0] # [m] corresponding vertical coordinates for ssp
            ssp = converted_list[:,1] # [m/s] sound speed profile, https://doi.org/10.5066/P9Y1MSTN
            ssp_cs = scipy.interpolate.CubicSpline(z_ssp, ssp)
    except FileNotFoundError:
        print(f"Error: {file} was not found.", file = ssp_filename)
    
    # initializing time values
    t_0 = 0 # [s] initial time
    dt = 1e-3 # [s] time interval
    
    z = np.array([z_0], dtype = np.float64) # [m] vertical coordinates
    x = np.array([0], dtype = np.float64) # [m] horizontal coordinates
    theta = np.array([theta_0], dtype = np.float64) # [rad] launch angle
    
    # each step will be equivalent in time
    iter = 0
    while dt*iter < 10:
    
        # get sound speed, sound speed gradient, and curvature @ initial point
        c = ssp_cs(z[iter])
        g = (ssp_cs(z[iter] + 1e-2) - ssp_cs(z[iter]))/1e-2
        R = -(1/g)*(c/np.cos(theta[iter]))
    
        # prepare next step in history of travel path
        theta = np.append(theta, 0)
        z = np.append(z, 0)
        x = np.append(x, 0)
    
        # populate next step in history of travel path
        theta[iter + 1] = theta[iter] - (c * dt)/R
    
        dz = R * (np.cos(theta[iter]) - np.cos(theta[iter + 1]))
        dx = np.abs(R * (np.sin(theta[iter]) - np.sin(theta[iter + 1])))
    
        z[iter + 1] = z[iter] + dz
        x[iter + 1] = x[iter] + dx
    
        if z[iter + 1] < 0: # switch the direction of theta to simulate bounce off ssb
    
            theta[iter + 1] = -np.arccos(z[iter]/R + np.cos(theta[iter])) # sign change for reflection
            dx = np.abs(R * (np.sin(theta[iter]) - np.sin(-theta[iter + 1]))) # sign change on theta[iter + 1] for pre-reflection
            x[iter + 1] = x[iter] + dx
            z[iter + 1] = 0
            dt_portion = R*(theta[iter] + theta[iter + 1])/c # sign change on theta[iter + 1] for pre-reflection
            iter += 1
    
            # prepare next step in history of travel path
            theta = np.append(theta, 0)
            z = np.append(z, 0)
            x = np.append(x, 0)
    
            # calculate new range and depth after bounce
            
            theta[iter + 1] = theta[iter] - (c * (dt - dt_portion))/R
            dz = np.abs(R * (np.cos(theta[iter]) - np.cos(theta[iter + 1])))
            dx = np.abs(R * (np.sin(theta[iter]) - np.sin(theta[iter + 1])))
            z[iter + 1] = dz
            x[iter + 1] = x[iter] + dx
    
        if z[iter + 1] > z_ssp[-1]: # switch the direction of theta to simulate bounce off shb
            
            # switch the direction of theta to simulate bounce off ssb
            theta[iter + 1] = np.arccos((z_ssp[-1] - z[iter])/R + np.cos(theta[iter])) # sign change for reflection
            dx = np.abs(R * (np.sin(theta[iter]) - np.sin(-theta[iter + 1])))
            x[iter + 1] = x[iter] + dx
            z[iter + 1] = z_ssp[-1]
            dt_portion = -R*(theta[iter] + theta[iter + 1])/c # sign change on theta[iter + 1] for pre-reflection
            iter += 1
    
            # prepare next step in history of travel path
            theta = np.append(theta, 0)
            z = np.append(z, 0)
            x = np.append(x, 0)
    
            # calculate new range and depth after bounce
            theta[iter + 1] = theta[iter] - (c * (dt - dt_portion))/R
            dz = R * (np.cos(theta[iter]) - np.cos(theta[iter + 1]))
            dx = np.abs(R * (np.sin(theta[iter]) - np.sin(theta[iter + 1])))
            z[iter + 1] = z[iter] + dz
            x[iter + 1] = x[iter] + dx
        
        iter += 1

    return [x, z]

fig = plt.figure(layout="constrained") 
gs = gridspec.GridSpec(nrows=3, ncols=6, figure=fig) 

ax1 = fig.add_subplot(gs[:,0])
ax2 = fig.add_subplot(gs[:,1:])

ax1.plot(ssp, z_ssp)
ax1.invert_yaxis()
zlims = ax1.get_ylim

for ii in np.arange(-5,5,1):
    [x, z] = ray_trace(z_0 = 200, theta_0 = ii)
    
    ax2.plot(x, z)
    ax2.set_ylim(ax1.get_ylim()[::-1])
    ax2.invert_yaxis()
